# %%
# Add my own libraries to the path
import sys
sys.path.append('/Users/Mead/Physics/library/python')

# Import libraries
import mead_field as field
import numpy as np
import matplotlib.pyplot as plt
#from mpl_toolkits.axes_grid1 import make_axes_locatable
import matplotlib as mpl
from scipy.special import gamma

# Ensure that plots are produced inline in the notebook
# %matplotlib inline

# Map parameters
pixels = 512 # Number of cells in map
map_size = 100. # Size of map [km]
periodic = False # Is the map periodic or not?
plot_size = 10 # Plot size [inches]
random_seed = None # Random number seed (can be None)

# Terrain parameters
shallow_depth = -100. # Depth above which water is 'shallow' [m]
beach_altitude = 0. # Altitude below which a beach is found [m]
mountain_altitude = 1000. # Altitude above which mountains are defined [m]
snow_altitude = 2000. # Altitude above which snowy mountains are defined [m]
desert_rain = 50. # Rainfall less than this qualifies as desert [mm/yr]
tropical_rain = 2000. # Rainfall greater than this qualifies as tropical [mm/yr]

# Altitude parameters
altitude_mean = 200. # Mean height above sea level [m]
altitude_sigma = 800. # Standard deviation for altitude [m]
altitude_smooth = 0.2*map_size # Maximum size of features in altitude [km]
altitude_index = -0.5 # Altitude power-law index
altitude_power = 3. # Power for non-linear field transformation

# Rainfall parameters
rainfall_mean = 1000. # Mean rainfall [mm/year]
rainfall_sigma = 2000. # Standard deviation of rainfall [mm/year] 
rainfall_smooth = 0.7*map_size # Maximum size of features in rainfall [km]
rainfall_index = -1.5 # Rainfall power-law index

# Power spectrum options
# 1 - Damping via exponential
# 2 - Damping via Gaussian
power_damping_method = 2

# Dictionary relating terrain types to integers and colors
terrain_dictionary = {
    'ocean': (0, 'blue'),
    'shallows': (1, 'deepskyblue'),
    'forest': (2, 'forestgreen'),
    'mountain': (3, 'sienna'),
    'snow': (4, 'snow'),
    'desert': (5, 'goldenrod'),
    'tropical': (6, 'limegreen')
}

# Function for the spatial power spectrum
if(power_damping_method == 1):
    def power_spectrum(k, A, n, kdamp):
        return A*(k**n)*np.exp(-k/kdamp)
    def normalisation(sigma, n, kdamp):
        return 2.*np.pi*sigma**2/(gamma(n+2)*kdamp**(n+2))
elif(power_damping_method == 2):
    def power_spectrum(k, A, n, kdamp):
        return A*(k**n)*np.exp(-k**2/(2.*kdamp**2))
    def normalisation(sigma, n, kdamp):
        return 2.*np.pi*sigma**2/(2.**(n/2)*gamma(n/2.+1.)*kdamp**(n+2))

# %%
# Checks
if(altitude_index <= -2.):
    raise ValueError('Altitude power-law index cannot be equal to or less than -2')  
if(rainfall_index <= -2.):
    raise ValueError('Rainfall power-law index cannot be equal to or less than -2')

# %%
# Calculations

# Fill colour map
# TODO: Add a loop here
#color_map = mpl.colors.ListedColormap(
#    [terrain_dictionary['ocean'][1], 
#     terrain_dictionary['shallows'][1], 
#     terrain_dictionary['forest'][1],
#     terrain_dictionary['mountain'][1],
#     terrain_dictionary['snow'][1],
#     terrain_dictionary['desert'][1],
#     terrain_dictionary['tropical'][1]
#    ])
#print(terrain_dictionary.values())
#color_map = mpl.colors.ListedColormap(terrain_dictionary.values)
colors = []
for values in terrain_dictionary.values():
    color = values[1]
    colors.append(color)
color_map = mpl.colors.ListedColormap(colors)
    
# Calculations
cell_size = map_size / np.real(pixels)
altitude_kdamp = 2.*np.pi/altitude_smooth
rainfall_kdamp = 2.*np.pi/rainfall_smooth
altitude_A = normalisation(altitude_sigma, altitude_index, altitude_kdamp)
rainfall_A = normalisation(rainfall_sigma, rainfall_index, rainfall_kdamp)

# Seed the random-number generator
np.random.seed(random_seed)

# %%
print('Map properties')
print('Map size [km]:', map_size)
print('Number of pixels per side:', pixels)
print('Cell size [km]:', cell_size)
print('Mountain height [m]:', mountain_altitude)
print('Snow line [m]:', snow_altitude)
print('Desert rain [mm/yr]:', desert_rain)
print('Tropical rain [mm/yr]:', tropical_rain)
print('')

print('Altitude properties')
print('Altitude mean [m]:', altitude_mean)
print('Altitude standard deviatiton [m]:', altitude_sigma)
print('Altitude power-law index:', altitude_index)
print('Altitude feature smoothing scale [km]:', altitude_smooth)
print('Altitude feature smoothing wavenumber [1/km]:', altitude_kdamp)
print('Altitude power normalisation [m^2 km^2]:', altitude_A)
print('Altitude power normalisation root [m km]:', np.sqrt(altitude_A))
print('')

print('Rainfall properties')
print('Rainfall mean [mm/yr]:', rainfall_mean)
print('Rainfall standard deviatiton [mm/yr]:', rainfall_sigma)
print('Rainfall power-law index:', rainfall_index)
print('Rainfall feature smoothing scale [km]:', rainfall_smooth)
print('Rainfall feature smoothing wavenumber [1/km]:', rainfall_kdamp)
print('Rainfall power normalisation [(mm/yr)^2 km^2]:', rainfall_A)
print('Rainfall power normalisation root [mm/yr km]:', np.sqrt(rainfall_A))
print('')
# Out:
# Map properties
# Map size [km]: 100.0
# Number of pixels per side: 512
# Cell size [km]: 0.1953125
# Mountain height [m]: 1000.0
# Snow line [m]: 2000.0
# Desert rain [mm/yr]: 50.0
# Tropical rain [mm/yr]: 2000.0
#
# Altitude properties
# Altitude mean [m]: 200.0
# Altitude standard deviatiton [m]: 800.0
# Altitude power-law index: -0.5
# Altitude feature smoothing scale [km]: 20.0
# Altitude feature smoothing wavenumber [1/km]: 0.3141592653589793
# Altitude power normalisation [m^2 km^2]: 22161989.089482803
# Altitude power normalisation root [m km]: 4707.652184420893
#
# Rainfall properties
# Rainfall mean [mm/yr]: 1000.0
# Rainfall standard deviatiton [mm/yr]: 2000.0
# Rainfall power-law index: -1.5
# Rainfall feature smoothing scale [km]: 70.0
# Rainfall feature smoothing wavenumber [1/km]: 0.08975979010256552
# Rainfall power normalisation [(mm/yr)^2 km^2]: 38912610.52346293
# Rainfall power normalisation root [mm/yr km]: 6237.99731672457

# %%
# Parameters for power spectrum plots
kmin = 2.*np.pi/map_size # Fundamental
kmax = pixels*np.pi/map_size  # Nyquist
nk = 101

# Set arrays to plot
k = np.logspace(np.log10(kmin), np.log10(kmax), nk)

for i in range(2):
    klab = 'k [1/km]'
    if(i == 0):
        Pk = power_spectrum(k, altitude_A, altitude_index, altitude_kdamp)       
        Pklab = 'P(k) [m^2 km^2]'
    elif(i == 1):
        Pk = power_spectrum(k, rainfall_A, rainfall_index, rainfall_kdamp)
        Pklab = 'P(k) [(mm/yr)^2 km^2]'
    plt.semilogx(k, Pk)
    #plt.plot(k, Pk)
    plt.xlabel(klab)
    plt.ylabel(Pklab)
    plt.show()

# %%
altitude = field.make_Gaussian_random_field_2D(altitude_mean, 
                                               power_spectrum, 
                                               map_size, 
                                               pixels,
                                               periodic,
                                               altitude_A, 
                                               altitude_index, 
                                               altitude_kdamp)

rainfall = field.make_Gaussian_random_field_2D(rainfall_mean, 
                                               power_spectrum, 
                                               map_size, 
                                               pixels,
                                               periodic,
                                               rainfall_A, 
                                               rainfall_index, 
                                               rainfall_kdamp)

for i in range(2):
    
    if(i==1):
        
        print('Applying transformations')
        print('')
        
        # Altitude transformations
        #altitude[altitude > 0.] = altitude*(altitude/2000.)**2
        #altitude[altitude < 0.] = altitude/2.
        altitude = altitude*np.absolute(altitude/snow_altitude)**(altitude_power-1.)
        #altitude = 0.*altitude+beach_altitude/2. # TODO: Remove

        # Rainfall transformations
        rainfall[rainfall < 0.] = 0. #Set rainfall to zero if less than zero?

    print('Altitude properties')
    print('Measured mean altitude [m]:', np.mean(altitude))
    print('Measured standard deviation of altitude [m]:', np.std(altitude))
    print('Ratio of measured to desired standard deviation of altitude:', np.std(altitude)/altitude_sigma)
    print('')

    print('Rainfall properties')
    print('Note that the standard deviation might be low due to no negative rainfall being enforced')
    print('Measured mean rainfall [mm/yr]:', np.mean(rainfall))
    print('Measured standard deviation of altitude [mm/yr]:', np.std(rainfall))
    print('Ratio of measured to desired standard deviation of altitude:', np.std(rainfall)/rainfall_sigma)
    print('')
# Out:
# Altitude properties
# Measured mean altitude [m]: 317.5693532742122
# Measured standard deviation of altitude [m]: 754.0079927823426
# Ratio of measured to desired standard deviation of altitude: 0.9425099909779283
#
# Rainfall properties
# Note that the standard deviation might be low due to no negative rainfall being enforced
# Measured mean rainfall [mm/yr]: 1268.956235925789
# Measured standard deviation of altitude [mm/yr]: 1139.6546515568918
# Ratio of measured to desired standard deviation of altitude: 0.569827325778446
#
# Applying transformations
#
# Altitude properties
# Measured mean altitude [m]: 141.40716988197485
# Measured standard deviation of altitude [m]: 479.7250706224021
# Ratio of measured to desired standard deviation of altitude: 0.5996563382780026
#
# Rainfall properties
# Note that the standard deviation might be low due to no negative rainfall being enforced
# Measured mean rainfall [mm/yr]: 1368.0680583094831
# Measured standard deviation of altitude [mm/yr]: 973.1525454388247
# Ratio of measured to desired standard deviation of altitude: 0.4865762727194124

# %%
# Array for the terrain integers
terrain_type = np.zeros((pixels, pixels), dtype=int)

# Decide upon the terrain types
for i in range(pixels):
    for j in range(pixels):
        alt = altitude[i, j]
        rain = rainfall[i, j]
        if(alt < shallow_depth):
            terrain = terrain_dictionary['ocean'][0]
        elif(alt >= shallow_depth and alt < 0.):
            terrain = terrain_dictionary['shallows'][0]
        elif(alt >= 0. and alt < beach_altitude):
            terrain = terrain_dictionary['desert'][0]
        elif(alt >= mountain_altitude and alt < snow_altitude):
            terrain = terrain_dictionary['mountain'][0]
        elif(alt >= mountain_altitude):
            terrain = terrain_dictionary['snow'][0]
        elif(alt >= beach_altitude and alt < mountain_altitude):
            if(rain <= desert_rain):
                terrain = terrain_dictionary['desert'][0]
            elif(rain >= tropical_rain):
                terrain = terrain_dictionary['tropical'][0]
            else:
                terrain = terrain_dictionary['forest'][0]
        else:
            raise ValueError('Terrain undefined')
        terrain_type[i, j] = terrain

# %%
peaks = field.find_field_peaks_2D(altitude, pixels, pixels, periodic)
print(peaks)
i, j = zip(*peaks)
#terrain_type[i, j] = terrain_dictionary['snow'][0]
# Out:
# [[0, 154], [0, 346], [0, 511], [2, 393], [3, 246], [7, 105], [11, 213], [13, 465], [18, 0], [36, 132], [38, 395], [40, 304], [41, 511], [58, 76], [58, 195], [61, 479], [68, 413], [69, 10], [75, 333], [77, 258], [82, 208], [96, 0], [101, 511], [107, 100], [107, 381], [110, 311], [114, 156], [128, 216], [138, 49], [150, 306], [150, 366], [151, 252], [158, 468], [175, 112], [179, 196], [184, 166], [187, 34], [187, 269], [205, 395], [209, 459], [212, 61], [221, 142], [232, 238], [246, 451], [249, 395], [256, 261], [257, 32], [262, 315], [265, 150], [273, 124], [281, 439], [282, 223], [305, 334], [308, 472], [309, 291], [311, 402], [320, 263], [327, 109], [328, 306], [329, 78], [331, 206], [350, 168], [351, 3], [351, 344], [353, 455], [362, 489], [369, 96], [369, 360], [374, 244], [378, 435], [395, 287], [403, 465], [416, 336], [420, 8], [422, 412], [424, 323], [425, 503], [426, 203], [437, 89], [441, 227], [455, 170], [461, 40], [469, 430], [472, 258], [474, 485], [483, 511], [484, 103], [488, 401], [497, 140], [500, 358], [507, 172], [511, 21], [511, 96], [511, 226], [511, 326], [511, 482]]

# %%
for i in range(3):
    plt.figure(figsize=(plot_size, plot_size))
    #ax = plt.gca()
    if (i == 0):
        plt.imshow(terrain_type, cmap=color_map, extent=[0.,map_size,0.,map_size],
                  vmin=0,
                  vmax=len(terrain_dictionary)
                  )
    elif (i == 1):
        scale = np.amax(np.absolute(altitude))
        image = plt.imshow(altitude, cmap=plt.cm.coolwarm, extent=[0.,map_size,0.,map_size],
                  vmin=-scale,
                  vmax=scale
                  )        
        color_bar_label = 'altitude [m]'        
    elif (i == 2):
        plt.imshow(rainfall, cmap=plt.cm.Blues, extent=[0.,map_size,0.,map_size],
                  vmin=0.,
                  vmax=np.amax(np.absolute(rainfall))
                  )
        color_bar_label = 'rainfall [mm/yr]'
    if(i == 1 or i == 2):
        #divider = make_axes_locatable(ax)
        #cax = divider.append_axes("right", size="5%", pad=0.10)
        #cbar = plt.colorbar(image, cax=cax)
        cbar = plt.colorbar()
        cbar.set_label(color_bar_label)
    plt.xlabel('km')
    plt.ylabel('km')
    plt.show()
